# %%
import pandas as pd

# %%
df_photo_exif_final=pd.read_csv('data/df_photo_exif_final.csv')

# %%
df_photo_exif_final.shape
# Out:
# (212932, 28)

# %%
df_photo_exif_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349306 entries, 0 to 349305
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Unnamed: 0                 349306 non-null  int64
#  1   id                         349306 non-null  float64
#  2   Image Width                56265 non-null   float64
#  3   Image Height               56277 non-null   float64
#  4   Compression                250467 non-null  object
#  5   Make                       288079 non-null  object
#  6   Model                      288222 non-null  object
#  7   Orientation                200500 non-null  object
#  8   Software                   276616 non-null  object
#  9   Date and Time (Modified)   297219 non-null  object
#  10  Exposure                   282688 non-null  object
#  11  Aperture                   281193 non-null  object
#  12  ISO Speed                  282048 non-null  object
# ...

# %%
df_photo_exif_final.head()
# Out:
#    Unnamed: 0            id  Image Width  Image Height       Compression  \
# 0           0  5.273375e+10          NaN           NaN  JPEG (old-style)
# 1           1  5.273424e+10          NaN           NaN  JPEG (old-style)
# 2           2  5.273417e+10          NaN           NaN  JPEG (old-style)
# 3           3  5.273375e+10          NaN           NaN  JPEG (old-style)
# 4           4  5.273375e+10          NaN           NaN  JPEG (old-style)
#
#     Make            Model          Orientation Software  \
# 0  Canon  Canon EOS 4000D  Horizontal (normal)      NaN
# 1  Canon  Canon EOS 4000D  Horizontal (normal)      NaN
# 2  Canon  Canon EOS 4000D  Horizontal (normal)      NaN
# 3  Canon  Canon EOS 4000D  Horizontal (normal)      NaN
# 4  Canon  Canon EOS 4000D  Horizontal (normal)      NaN
#
#   Date and Time (Modified)  ...          owner      secret     title lat lon  \
# 0      2023:03:07 00:30:12  ...  197843899@N04  e583f820c8  IMG_1798  na  na
# ...

# %%
df_photo_exif_final.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Image Width', 'Image Height', 'Compression',
#        'Make', 'Model', 'Orientation', 'Software', 'Date and Time (Modified)',
#        'Exposure', 'Aperture', 'ISO Speed', 'Date and Time (Original)',
#        'Date and Time (Digitized)', 'Flash', 'Focal Length', 'White Balance',
#        'owner', 'secret', 'title', 'lat', 'lon', 'acc', 'country',
#        'admin_lvl1', 'admin_lvl2', 'city'],
#       dtype='object')

# %%
df_photo_exif_final.sample()
# Out:
#        Unnamed: 0            id  Image Width  Image Height       Compression  \
# 37465       54925  5.315957e+10          NaN           NaN  JPEG (old-style)
#
#                     Make        Model   Orientation  Software  \
# 37465  NIKON CORPORATION  NIKON D7500  Rotate 90 CW  Ver.1.10
#
#       Date and Time (Modified)  ...          owner      secret  \
# 37465      2023:07:26 11:37:37  ...  198979198@N08  71712c303c
#
#                                                    title lat lon acc country  \
# 37465  Alis German working drone Beritzulma in Friese...  na  na  na      na
#
#       admin_lvl1 admin_lvl2 city
# 37465         na         na   na
#
# [1 rows x 28 columns]

# %%
df_photo_exif_final.columns=df_photo_exif_final.columns.str.lower().str.replace(' ','_')

# %%
df_photo_exif_final.head()
# Out:
#    unnamed:_0            id  image_width  image_height       compression  \
# 0           0  5.273375e+10          NaN           NaN  JPEG (old-style)
# 1           1  5.273424e+10          NaN           NaN  JPEG (old-style)
# 2           2  5.273417e+10          NaN           NaN  JPEG (old-style)
# 3           3  5.273375e+10          NaN           NaN  JPEG (old-style)
# 4           4  5.273375e+10          NaN           NaN  JPEG (old-style)
#
#     make            model          orientation software  \
# 0  Canon  Canon EOS 4000D  Horizontal (normal)      NaN
# 1  Canon  Canon EOS 4000D  Horizontal (normal)      NaN
# 2  Canon  Canon EOS 4000D  Horizontal (normal)      NaN
# 3  Canon  Canon EOS 4000D  Horizontal (normal)      NaN
# 4  Canon  Canon EOS 4000D  Horizontal (normal)      NaN
#
#   date_and_time_(modified)  ...          owner      secret     title lat lon  \
# 0      2023:03:07 00:30:12  ...  197843899@N04  e583f820c8  IMG_1798  na  na
# ...

# %%
df_photo_exif_final['make'].value_counts()
# Out:
# Canon                99207
# NIKON CORPORATION    56838
# SONY                 29370
# Apple                29194
# Panasonic            16560
#                      ...
# Energy_Sistem            1
# isopropan 0.3/20         1
# Agfa                     1
# Intrepid                 1
# Voigtlander              1
# Name: make, Length: 389, dtype: int64

# %%
df_photo_exif_final['model'].value_counts()
# Out:
# Canon EOS 7D Mark II                            10363
# Canon EOS 5D Mark IV                             7734
# Canon EOS R5                                     5540
# Canon EOS 6D                                     4788
# Canon EOS 5D Mark III                            4701
#                                                 ...
# KODAK Z730 ZOOM DIGITAL CAMERA                      1
# SP590UZ                                             1
# KODAK EasyShare Z980 Digital Camera                 1
# DCR-DVD405                                          1
# Rollei Powerflex 350 WIFI                           1
# Name: model, Length: 3942, dtype: int64

# %%
df_photo_exif_final['id'].value_counts()
# Out:
# 5.319341e+10    18
# 5.319239e+10    16
# 5.318249e+10    16
# 5.311114e+10    15
# 5.312553e+10    15
#                 ..
# 5.312982e+10     1
# 5.313023e+10     1
# 5.313030e+10     1
# 5.312923e+10     1
# 5.026526e+10     1
# Name: id, Length: 268269, dtype: int64

# %%
# df_canon=pd.DataFrame([])
# for make in df_photo_exif_final:
#     if make == 'Canon':
#         df_canon.concat([pd.DataFrame([make])])

# %%
df_photo_exif_final['make']
# Out:
# 0         Canon
# 1         Canon
# 2         Canon
# 3         Canon
# 4         Canon
#           ...
# 349301    Canon
# 349302    Canon
# 349303    Canon
# 349304    Canon
# 349305    Canon
# Name: make, Length: 349306, dtype: object

# %%
df_canon.info()

# %%
df_photo_exif_final.owner.value_counts()
# Out:
# 123597211@N03    6399
# 151639852@N07    2348
# 133876835@N08    2233
# 71296413@N02     2062
# 82714141@N00     1459
#                  ...
# 72899439@N00        1
# 92762586@N06        1
# 71649947@N00        1
# 66119424@N03        1
# 35939355@N04        1
# Name: owner, Length: 38801, dtype: int64

# %%
df_unique_owner=df_photo_exif_final.owner.value_counts()

# %%
type(df_unique_owner)
# Out:
# pandas.core.series.Series

# %%
df_unique_owner=df_unique_owner.to_dict()

# %%
df_unique_owner
# Out:
# {'123597211@N03': 6399,
#  '151639852@N07': 2348,
#  '133876835@N08': 2233,
#  '71296413@N02': 2062,
#  '82714141@N00': 1459,
#  '39415781@N06': 1449,
#  '91044419@N08': 1343,
#  '96869121@N03': 1052,
#  '24914070@N07': 948,
#  '23465276@N04': 931,
#  '193346920@N05': 924,
#  '10786053@N05': 880,
#  '130826713@N02': 844,
#  '197637656@N02': 843,
#  '51425650@N04': 840,
#  '184741656@N05': 806,
#  '39289177@N05': 759,
#  '98336874@N04': 756,
#  '187385029@N08': 753,
#  '198517374@N07': 718,
#  '150203634@N08': 716,
#  '77522429@N02': 712,
#  '44240523@N06': 700,
#  '137994940@N08': 698,
#  '44884174@N08': 693,
#  '97019847@N00': 688,
#  '42332371@N00': 669,
#  '39143042@N04': 644,
#  '187113622@N05': 634,
#  '11169641@N06': 626,
#  '139375961@N08': 603,
#  '198715600@N03': 595,
#  '30629882@N08': 592,
#  '115081346@N06': 588,
#  '140377809@N05': 579,
#  '80161911@N00': 568,
#  '43062973@N00': 564,
#  '24141292@N02': 553,
#  '154104874@N04': 553,
#  '36085842@N06': 549,
# ...

# %%
df_photo_exif_final.shape
# Out:
# (349306, 28)
